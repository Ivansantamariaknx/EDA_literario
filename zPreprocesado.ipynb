# %%
import pandas as pd
import numpy as np

# %%
Datosagr=["Mi proyecto\Data\ESPAUTOMATICAS.csv","Mi proyecto\Data\ESPBROAD.csv","Mi proyecto\Data\ESPKINDLE.csv","Mi proyecto\Data\ESPPALABRASCONVIRTIERON.csv"]

# %%
Muestra=[]
for archivos in Datosagr:
 df=pd.read_csv(archivos)
 Muestra.append(df)

# %%
df_combinado = pd.concat(Muestra, ignore_index=True)
df_combinado
# Out:
#                   Producto que coincide         Objetivos de productos  \
# 0                    libros adolescentes                   loose-match
# 1                         saga de libros                   loose-match
# 2                             1408855658                   substitutes
# 3    libros para adolescentes de 14 años                   loose-match
# 4                             8417854517                   substitutes
# ..                                   ...                           ...
# 298                     libros juveniles                 libro juvenil
# 299         libros para niñas de 14 años  libros para niños de 14 años
# 300      libro adolescentes 12 años niño             libro adolescente
# 301                       libros 13 años                 libro 13 años
# 302            libro de fantasia juvenil        libro fantasia juvenil
#
#     Añadido como  Impresiones  Clics Porcentaje de clics (CTR)  Gasto(EUR)  \
# ...

# %%
import seaborn as sns

# %%
1. Las 5 kw más rentables (Hay que obtener la rentabilidad)
2. Las 5 kw más costosas
3. Las 10 kw menos efectivas
4. El grupo de anuncios con más ventas
6. El CPC medio
7. El coste de obtener una ventas
8. Resultados por coincidencia
9. Mejores Asins competidores para pujar
10. Mayor ratio impresión click
11. Mas ventas
12. Más clicados
13. Menos efectivos
14. Campaña más efectiva
15. Formulas estadisticas random (mediana y esas cosas)

# %%
#añado columna de rentabilidad
df_combinado ["rentabilidad"]= df_combinado['Gasto(EUR)'] /df_combinado['Ventas(EUR)']
df_combinado
# Out:
#                   Producto que coincide         Objetivos de productos  \
# 0                    libros adolescentes                   loose-match
# 1                         saga de libros                   loose-match
# 2                             1408855658                   substitutes
# 3    libros para adolescentes de 14 años                   loose-match
# 4                             8417854517                   substitutes
# ..                                   ...                           ...
# 298                     libros juveniles                 libro juvenil
# 299         libros para niñas de 14 años  libros para niños de 14 años
# 300      libro adolescentes 12 años niño             libro adolescente
# 301                       libros 13 años                 libro 13 años
# 302            libro de fantasia juvenil        libro fantasia juvenil
#
#     Añadido como  Impresiones  Clics Porcentaje de clics (CTR)  Gasto(EUR)  \
# ...

# %%
#11 Top 3 más ventas
df_combinado["Ventas(EUR)"].max()

df_combinado.loc[df_combinado["Ventas(EUR)"] == df_combinado["Ventas(EUR)"].max()]
# Out:
#                 Producto que coincide  Objetivos de productos Añadido como  \
# 135  libros 12 años mas vendidos niños            loose-match          NaN
#
#      Impresiones  Clics Porcentaje de clics (CTR)  Gasto(EUR)  CPC(EUR)  \
# 135           23      7                     30,43       11.05      1.58
#
#      Pedidos  Ventas(EUR)       ACOS      ROAS  Ratio de conversión  \
# 135        2        33.84  32.653664  3.062443            28.571429
#
#      rentabilidad
# 135      0.326537

# %%
df_combinado.query("Stock>0")
