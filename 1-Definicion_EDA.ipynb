# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown

# %% [markdown]
# ## Análisis Ads La Decisión de la Espada

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown

# %% [markdown]
# La Decisión de la Espada tiene anuncios en Amazon, el objetivo de este proyecto es obtener información relevante

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Puede que tengas más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
El objetivo principal es obtener las Keywords más rentables en la publicación de anuncios.

# %%
# Escribe más hipótesis si las hubiera en Markdown

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una breve descripción del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
Las fuentes utilizadas para realizar el análisis son las distintas búsquedas que el libro ha tenido por anuncios en Amazon durante los últimos 65 días (plazo máximo permitido por la herramienta de Ads). La fuente es por tanto https://advertising.amazon.es

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset

# %%
import pandas as pd
import numpy as np

# %%
automatica= pd.read_csv('Mi proyecto\Data\ESPAUTOMATICAS.csv',  index_col=0)
automatica.head()
# Out:
#                                     Objetivos de productos Añadido como  \
# Producto que coincide
# libros adolescentes                            loose-match          NaN
# saga de libros                                 loose-match          NaN
# 1408855658                                     substitutes          NaN
# libros para adolescentes de 14 años            loose-match          NaN
# 8417854517                                     substitutes          NaN
#
#                                      Impresiones  Clics  \
# Producto que coincide
# libros adolescentes                          206      9
# saga de libros                                 3      1
# 1408855658                                    21      1
# libros para adolescentes de 14 años            5      2
# 8417854517                                   261      3
#
#                                     Porcentaje de clics (CTR)  Gasto(EUR)  \
# Producto que coincide
# ...

# %%
# Siguiente dataset...

# %%
broad= pd.read_csv('Mi proyecto\Data\ESPBROAD.csv',  index_col=0)
broad.head()
# Out:
#                                                             Objetivos de productos  \
# Producto que coincide
# libros juveniles                                                  libros juveniles
# laura gallego                                                        laura gallego
# libros de misterio y suspense para adolescentes           libros para adolescentes
# libros mas vendidos niños 12 años                libros niños 12 años mas vendidos
# libros para adolescentes                                        libro adolescentes
#
#                                                                             Añadido como  \
# Producto que coincide
# libros juveniles                                           Palabra clave: exacta, amplia
# laura gallego                                    Palabra clave: exacta, amplia, de frase
# libros de misterio y suspense para adolescentes                                      NaN
# ...

# %%
kindle=pd.read_csv('Mi proyecto\Data\ESPKINDLE.csv',index_col=0)
kindle.head()
# Out:
#                              Objetivos de productos Añadido como  Impresiones  \
# Producto que coincide
# libros kindle juveniles                 loose-match          NaN           12
# una corte de espinas y rosas            loose-match          NaN           55
# libros fantasía juvenil                 loose-match          NaN            1
# libros baratos                          loose-match          NaN           14
# b07y6mhnts                              complements          NaN           26
#
#                               Clics Porcentaje de clics (CTR)  Gasto(EUR)  \
# Producto que coincide
# libros kindle juveniles           1                      8,33        0.79
# una corte de espinas y rosas      1                      1,82        0.30
# libros fantasía juvenil           1                    100,00        0.85
# libros baratos                    2                     14,29        1.42
# b07y6mhnts                        1                      3,85        0.73
#
# ...

# %%
convirt=pd.read_csv('Mi proyecto\Data\ESPPALABRASCONVIRTIERON.csv',index_col=0)
convirt.head()
# Out:
#                                        Objetivos de productos  \
# Producto que coincide
# libros 13 años mas vendidos niños               libro 13 años
# libros adolescentes 13 años        libro adolescentes 13 años
# libros juveniles 12 años                libro juvenil 12 años
# libros para adolescentes                    libro adolescente
# libros fantasía juvenil                libro fantasia juvenil
#
#                                               Añadido como  Impresiones  \
# Producto que coincide
# libros 13 años mas vendidos niños  Palabra clave: de frase            1
# libros adolescentes 13 años        Palabra clave: de frase           22
# libros juveniles 12 años           Palabra clave: de frase           84
# libros para adolescentes                               NaN          771
# libros fantasía juvenil                                NaN            7
#
#                                    Clics Porcentaje de clics (CTR)  \
# Producto que coincide
# ...
